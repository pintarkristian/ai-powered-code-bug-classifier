# %% [markdown]
# # Exploratory Data Analysis\n\nPlaceholder notebook for inspecting code classification datasets.

# %%
from pathlib import Path\nimport pandas as pd\n\nDATA_PATH = Path('../data/processed/train.csv')\nprint(f'Dataset exists: {DATA_PATH.exists()}')
